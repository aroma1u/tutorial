# %%
# Function to calculate and display the investment growth
def calculate_compound_interest():
    print("Compound Interest Investment Growth Calculator")
    print("---------------------------------------------")

    # 1. Ask the user to input
    
    # Get initial investment amount
    while True:
        try:
            initial_amount = float(input("Enter the initial investment amount (e.g., 1000): "))
            if initial_amount >= 0:
                break
            else:
                print("Investment must be a positive number. Please try again.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

    # Get annual interest rate
    while True:
        try:
            annual_rate_percent = float(input("Enter the annual interest rate (in percentage, e.g., 5 for 5%): "))
            if annual_rate_percent >= 0:
                break
            else:
                print("Interest rate must be a positive number. Please try again.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")
            
    # Get number of years
    while True:
        try:
            years = int(input("Enter the number of years: "))
            if years > 0:
                break
            else:
                print("Number of years must be a positive integer. Please try again.")
        except ValueError:
            print("Invalid input. Please enter a valid whole number for years.")

    # Initialize the current amount with the initial investment
    current_amount = initial_amount

    # Prepare the table header
    print("\nInvestment Growth Summary:")
    print("-" * 23)
    print(f"{'Year':<5}{'Amount':>15}")
    print(f"{'-' * 5}{'-' * 15}")

    # 2. Use a loop to calculate the amount at the end of each year
    for year in range(1, years + 1):
        # Calculate the interest for the year
        # The formula given is: Amount = amount + (amount * (annual interest rate / 100))
        interest_gained = current_amount * (annual_rate_percent / 100)
        current_amount += interest_gained
        
        # 3. Display the year number and the amount rounded to two decimal places
        # Using f-strings for formatted output: <5 for left-align year, >15.2f for right-align amount
        print(f"{year:<5}{current_amount:>15.2f}")

    print("-" * 23)
    print(f"Final Value after {years} years: ${current_amount:.2f}")

# Execute the function
calculate_compound_interest()
# Out:
# Compound Interest Investment Growth Calculator
# ---------------------------------------------
# Enter the initial investment amount (e.g., 1000):  1000
# Enter the annual interest rate (in percentage, e.g., 5 for 5%):  5
# Enter the number of years:  3
# Investment Growth Summary:
# -----------------------
# Year          Amount
# --------------------
# 1            1050.00
# 2            1102.50
# 3            1157.62
# -----------------------
# Final Value after 3 years: $1157.62
